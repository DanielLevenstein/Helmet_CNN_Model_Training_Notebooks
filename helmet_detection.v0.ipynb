# %% [markdown]
# # HelmNet Helmet Detection School Project
# Model0 was created as part of a school project at UT. [HelmNet_ImageProcessing_Notebook](https://github.com/DanielLevenstein/HelmNet_ImageProcessing_UT_ML_Project6/)
#
#
# ## Streamlit App
#
# This model performed really well on training data but incredibly poorly on unseen data, and was the initial inspiration for the streamlit app I wrote allowing direct comparisons of different models.
#
#
# * [DanielLevenstein/Helmet_CNN_Data_Quality_Case_Study](https://huggingface.co/spaces/DanielLevenstein/Helmet_Image_Classification)
#
# ## Training Data
# A sample of images from the training notebook has been extracted for documentation purposes.
# ![dataset0_sample_images.png](charts/dataset0_sample_images.png)

# %% [markdown]
# ## Conclusion Summary
# Because of low-quality training data, I initially set a confidence threshold (0.95) on final outputs.
# This appeared to improve clear performance in the notebook, but it did not eliminate false positives on unseen data.
# The confidence threshold has been set back to .50 in the latest version of the streamlit app.
